# %% [markdown]
# # Random Forest with default setting

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    Plots confusion matrix,
    cm - confusion matrix
    """
    plt.figure(1, figsize=(5, 5), dpi=160)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# fit random forest model
model_rf = RandomForestClassifier()
model_rf.fit(X_trainFlat, Y_train)
pred = model_rf.predict(X_testFlat)

# %%
# print the result
print("Classification report for classifier %s:\n%s\n"
% (model_rf, metrics.classification_report(Y_test, pred)))
cm = metrics.confusion_matrix(Y_test, pred)
plot_confusion_matrix(cm)
print("Accuracy={}".format(metrics.accuracy_score(Y_test, pred)))
# Out:
# Classification report for classifier RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False):
#              precision    recall  f1-score   support
#
#           0       0.81      0.98      0.89        48
#           1       0.72      0.88      0.79        50
#           2       0.87      0.96      0.91        48
#           3       0.93      1.00      0.96        50
#           4       0.86      0.60      0.71        50
#           5       0.87      0.92      0.89        50
#           6       0.87      0.78      0.82        50
#           7       0.89      0.82      0.85        50
# ...
